# %%
import requests
import json
import time

def_apikey = "0BA43288A7"
def_ip = "192.168.178.37"
def_port = "80"
def_merged = "http://"+def_ip+":"+def_port+"/api/"+def_apikey

#wofür bist du da? funktioniert nicht.
def get_current_state(ip, port):
    url = "http://"+ip+":"+port+"/evaluate"
    #print(url)
    r = requests.post(url)
    return r.text

# Checks if the light is on
def isLightOn(lightNum):
    url = def_merged+"/lights/"+str(lightNum)
    r = requests.get(url)
    
    response = str(r)
    checkingFor = "\"on\": true"
           
    #checks if the string contains a certain string (substring function)
    if(response.find(checkingFor)): 
        return True
    
    return False
    
# changes the light
def change_light(colorNumber):
    red = 60872
    green = 25600
    blue = 47104
    color = 0
    url = def_merged+"/lights/1/state"
    if colorNumber == 1:
    	color = blue
    elif colorNumber == 2:
        color = red
    elif colorNumber == 3:
        color = green
    
    #print(color)
    data = {
        "on": True,
        "hue": color,
        "transitiontime": 50
    }
    
    payload = json.dumps(data)
    #print(payload)
    
    try:
        r = requests.put(url, data=payload)
        print(r.status_code)
    except:
        print("There was a connection error")


def_ip = "192.168.178.37"
def_port = "80"

def run():
    while (True):
        response = str(lgt.get_current_state(def_ip, def_port))
        print(response)
        lgt.change_light(1)
        time.sleep(10)
        # Erst State vom Server Holen
        # Dann Hue anpassen

if __name__ == "__main__":
    
    print(isLightOn(1))
        
    i = 1    
    while(i <= 3):
        change_light(i)
        time.sleep(5)
        i = i+1
    #run()
# Out:
# True
# 200
# 200
# 200

# %%
#!/usr/local/bin/python
# -*- coding: utf-8 -*-

import pyaudio
import numpy as np
import requests
import time

LOW_BRI = 0
MAX_BRI = 254
MAX_HUE = 65534

chunk = 2**10
rate = 22050
fft_selection_filter = 12
hue_cycle_speed = 500
activation_threshold = 10000
run_time = 10 #in sec
user_id = '0BA43288A7'
hue_bridge_ip = '192.168.178.37'

p=pyaudio.PyAudio()
stream=p.open(format=pyaudio.paInt16,channels=1,rate=rate,input=True,
              frames_per_buffer=chunk, input_device_index=0)

previous_bri = LOW_BRI
for i_data_blocks in range(run_time*rate/chunk):
    data = np.fromstring(stream.read(chunk),dtype=np.int16)
    fft = np.fft.fft(data)
    hue = str((i_data_blocks*hue_cycle_speed)%MAX_HUE)
    bri = int(np.absolute(np.average(fft[0:fft_selection_filter])))
    if bri < activation_threshold:
        bri = LOW_BRI
    else:
        bri = MAX_BRI
    if bri != previous_bri:
        r_1 = requests.put('http://' + hue_bridge_ip + '/api/' + user_id +'/lights/1/state',
            data='{"bri": ' + str(bri) +', "transitiontime" : 1, "hue": ' + hue +'}')
        #r_2 = requests.put('http://' + hue_bridge_ip + '/api/' + user_id +'/lights/2/state',
            #data='{"bri": ' + str(bri) +', "transitiontime" : 1, "hue": ' + hue +'}')
        if bri:
            print("--High")
        else:
            print("-Low")
    previous_bri = bri
stream.stop_stream()
stream.close()
p.terminate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9469f1d9d274> in <module>()
#      25
#      26 previous_bri = LOW_BRI
# ---> 27 for i_data_blocks in range(run_time*rate/chunk):
#      28     data = np.fromstring(stream.read(chunk),dtype=np.int16)
#      29     fft = np.fft.fft(data)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
import sys
# !conda install --yes --prefix {sys.prefix} pyaudio
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\Anaconda3
#
#   added / updated specs:
#     - pyaudio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2018.11.29         |           py37_0         146 KB
#     pyaudio-0.2.11             |   py37hfa6e2cd_1          34 KB
#     portaudio-19.6.0           |       hfa6e2cd_3         511 KB
#     ------------------------------------------------------------
#                                            Total:         691 KB
#
# The following NEW packages will be INSTALLED:
#
#     portaudio: 19.6.0-hfa6e2cd_3
#     pyaudio:   0.2.11-py37hfa6e2cd_1
#
# The following packages will be UPDATED:
#
#     certifi:   2018.8.24-py37_1      --> 2018.11.29-py37_0
#
#
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# certifi-2018.11.29   | 146 KB    |            |   0%
# certifi-2018.11.29   | 146 KB    | ########## | 100%
#
# pyaudio-0.2.11       | 34 KB     |            |   0%
# pyaudio-0.2.11       | 34 KB     | ###5       |  35%
# pyaudio-0.2.11       | 34 KB     | ########## | 100%
#
# portaudio-19.6.0     | 511 KB    |            |   0%
# portaudio-19.6.0     | 511 KB    | 2          |   2%
# portaudio-19.6.0     | 511 KB    | ######5    |  66%
# portaudio-19.6.0     | 511 KB    | ########9  |  90%
# portaudio-19.6.0     | 511 KB    | ########## | 100%

# %%
"""PyAudio Example: Play a WAVE file."""

import pyaudio
import struct
import numpy as np
#import matplotlib.pyplot as plt

CHUNK = 1024 * 4
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100

p = pyaudio.PyAudio()

stream = p.open(
    format=FORMAT,
    channels=CHANNELS,
    rate=RATE,
    input=True,
    output=True,
    frames_per_buffer=CHUNK
)

data = stream.read(CHUNK)
data
# Out:
# b'\x ...
